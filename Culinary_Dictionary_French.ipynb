# %%
## Reading in a URL
import requests

url = 'https://stripedspatula.com/resources/french-cooking-terms/'
f = requests.get(url)
text = f.text
print(text)
f.close()
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# ...
