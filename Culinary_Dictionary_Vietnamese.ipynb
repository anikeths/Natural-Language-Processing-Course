# %%
## Reading in a URL
import requests

url = 'https://www.popsugar.com/food/Vietnamese-Food-Glossary-18692830'
f = requests.get(url)
text = f.text
print(text)
f.close()
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US" dir="ltr">
#     <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
#
#         <meta charset="utf-8">
#                                             <link rel="dns-prefetch" href="https://media1.popsugar-assets.com" />
#                 <link rel="preconnect" href="https://media1.popsugar-assets.com/" />
#                             <link rel="dns-prefetch" href="https://www.google-analytics.com" />
#                 <link rel="preconnect" href="https://www.google-analytics.com/" />
#                             <link rel="dns-prefetch" href="https://beacon.krxd.net" />
#                 <link rel="preconnect" href="https://beacon.krxd.net/" />
#                             <link rel="dns-prefetch" href="https://cdn.krxd.net" />
#                 <link rel="preconnect" href="https://cdn.krxd.net/" />
# ...
